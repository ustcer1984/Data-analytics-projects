# %%
import pandas as pd
from src.ScoreModels import *
import json
import pickle

# %%
kwargs_Linear = json.load(open('./params/Linear.json', 'r'))
kwargs_KNN = json.load(open('./params/KNN.json', 'r'))
kwargs_XGB = json.load(open('./params/XGB.json', 'r'))

# %%
p_Linear = ScorePipelineLinear(**kwargs_Linear)
p_KNN = ScorePipelineKNN(**kwargs_KNN)
p_XGB = ScorePipelineXGB(**kwargs_XGB)

# %%
p_Linear.fit(**kwargs_Linear)
# Out:
# 2024-04-12 01:09:41.804597
# Pipeline activated.
#   blueprint = main
#   mode = train
# 2024-04-12 01:09:41.804597
# 0 Load raw data: startDone!
# 2024-04-12 01:09:41.899102
# 1 Common data cleaning + feature engineering: Done!
# 2024-04-12 01:09:42.117511
# 2 Prepare corss-validate datasets: Done!
# 2024-04-12 01:09:45.404572
# 3 Apply StandardScaler transform to cv datasets: Done!
# 2024-04-12 01:09:45.456169
# 4 Fill null values in attendance_rate:
# [I 2024-04-12 01:09:46,119] A new study created in memory with name: no-name-126763e5-0f1f-4373-bef2-46fdd52308c8
# Done!
# 2024-04-12 01:09:46.119218
# 5 Model hyper parameter tuning: start
# [I 2024-04-12 01:09:46,621] Trial 6 finished with value: 13.976472818577102 and parameters: {'poly_degree': 1, 'alpha': 7.734295175145166, 'l1_ratio': 0.9573067186057194}. Best is trial 6 with value: 13.976472818577102.
# ...

# %%
p_KNN.fit(**kwargs_KNN)
# Out:
# 2024-04-12 02:50:12.699398
# Pipeline activated.
#   blueprint = main
#   mode = train
# 2024-04-12 02:50:12.700436
# 0 Load raw data: startDone!
# 2024-04-12 02:50:12.813843
# 1 Common data cleaning + feature engineering: Done!
# 2024-04-12 02:50:13.057557
# 2 Prepare corss-validate datasets: Done!
# 2024-04-12 02:50:16.525723
# 3 Apply StandardScaler transform to cv datasets: Done!
# 2024-04-12 02:50:16.578496
# 4 Fill null values in attendance_rate:
# [I 2024-04-12 02:50:17,252] A new study created in memory with name: no-name-e1861412-35eb-45f7-803b-0fb0dcd8daf1
# Done!
# 2024-04-12 02:50:17.252431
# 5 Model hyper parameter tuning: start
# [I 2024-04-12 02:52:00,058] Trial 11 finished with value: 8.391256319969642 and parameters: {'n_neighbors': 77, 'weights': 'distance', 'p': 1.022206263147598}. Best is trial 11 with value: 8.391256319969642.
# ...

# %%
p_XGB.fit(**kwargs_XGB)
# Out:
# 2024-04-12 04:43:01.199182
# Pipeline activated.
#   blueprint = main
#   mode = train
# 2024-04-12 04:43:01.200181
# 0 Load raw data: startDone!
# 2024-04-12 04:43:01.318446
# 1 Common data cleaning + feature engineering: Done!
# 2024-04-12 04:43:01.555350
# 2 Prepare corss-validate datasets: Done!
# 2024-04-12 04:43:05.046706
# 3 Fill null values in attendance_rate:
# [I 2024-04-12 04:43:05,732] A new study created in memory with name: no-name-e45dc891-1ce9-4e6a-abd9-755c7b59adf4
# Done!
# 2024-04-12 04:43:05.732710
# 4 Model hyper parameter tuning: start
# ...
